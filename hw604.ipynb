# %% [markdown]
# <a href="https://colab.research.google.com/github/jc7qx/mcu2026-mlai-hw604/blob/main/hw604.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ˋ

# %% [markdown]
# # homework 604
#
# 1. 請下載鐵達尼號資料檔
# 2. 使用xgboost建立預測模型，計算模型效能
# 3. 下載鳶尾花資料檔
# 4. 使用Random Forest建立預測模型，利用grid search執行超參數校對，找出最佳模型。
